# %%
import pandas as pd
import numpy as np

# %%
dataf = pd.read_csv(r"C:\Users\muralidharan.m\Desktop\Predict Cab Price.csv")

# %%
dataf
# Out:
#     miles  temp  rain  ncabs  price
# 0       1    30     0     10     20
# 1       1    38     0      5     40
# 2       1    25     0      1     50
# 3       1    20     1     10     50
# 4       1    15     1      4     80
# 5       1    10     1      2    200
# 6       2    30     0     10     30
# 7       2    38     0      5     50
# 8       2    25     0      1     90
# 9       2    20     1     10     90
# 10      2    15     1      4    120
# 11      2    10     1      2    250
# 12      3    30     0     10     50
# 13      3    38     0      5     80
# 14      3    25     0      1     96
# 15      3    20     1     10    110
# 16      3    15     1      4    122
# 17      3    10     1      2    333
# 18      4    30     0     10     87
# 19      4    38     0      5    144
# 20      4    25     0      1    170
# 21      4    20     1     10    255
# 22      4    15     1      4    180
# 23      4    10     1      2    424
# 24      5    30     0     10    144
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(dataf[['ncabs']],dataf['price'])
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([-12.41110992])

# %%
model.intercept_
# Out:
# 224.9101787434443

# %%
dataf
# Out:
#     miles  temp  rain  ncabs  price
# 0       1    30     0     10     20
# 1       1    38     0      5     40
# 2       1    25     0      1     50
# 3       1    20     1     10     50
# 4       1    15     1      4     80
# 5       1    10     1      2    200
# 6       2    30     0     10     30
# 7       2    38     0      5     50
# 8       2    25     0      1     90
# 9       2    20     1     10     90
# 10      2    15     1      4    120
# 11      2    10     1      2    250
# 12      3    30     0     10     50
# 13      3    38     0      5     80
# 14      3    25     0      1     96
# 15      3    20     1     10    110
# 16      3    15     1      4    122
# 17      3    10     1      2    333
# 18      4    30     0     10     87
# 19      4    38     0      5    144
# 20      4    25     0      1    170
# 21      4    20     1     10    255
# 22      4    15     1      4    180
# 23      4    10     1      2    424
# 24      5    30     0     10    144
# ...

# %%
model.predict(dataf[['ncabs']])
model_pred_price = model.predict(dataf[['ncabs']])
actual_price = dataf['price']

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(actual_price, model_pred_price)
# Out:
# 12133.723231652932

# %%
mean_absolute_error(actual_price, model_pred_price) #MAE
# Out:
# 80.58182097113702

# %%
np.sqrt(mean_squared_error(actual_price, model_pred_price))
# Out:
# 110.15318076048885

# %%
r2_score(actual_price, model_pred_price)
# Out:
# 0.1414342443406591

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

mean_absolute_percentage_error(actual_price, model_pred_price)
# Out:
# 83.78225074689455

# %%
import matplotlib.pyplot as plt
plt.scatter(dataf["ncabs"],dataf["price"],color = 'brown')
plt.plot(dataf['ncabs'],model_pred_price, color= 'b')
plt.show()
